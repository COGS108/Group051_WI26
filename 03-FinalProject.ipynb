# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# ## Link to video
# https://youtu.be/S_KlLIV3aao?si=2URcULXgLdjWE3Hs
#
# ## Abstract
#
# In rhythm games, new players have the tendency to struggle with an appropriate difficulty to try out and are often left discouraged to pursue a rhythm game further. One instance in particular would be in the rhythm game Dance Dance Revolution (DDR), where overlapping labels can make it hard for a new player to identify their current skill level. Our project aims to investigate whether the performance on a DDR chart can reliably predict a player’s skill across charts of varying difficulty. Using gameplay statistics gathered from experienced DDR players sharing their scores, we analyzed how core skills used for DDR can potentially be generalized across DDR’s numeric ratings 1-20. We found the relevance of chart ratings pushing the extent of core skills as the difficulty goes up to accuracy metrics like EX scores (DDR’s accuracy based scoring system); applying statistical models to evaluate the strength of this relationship. Using our foundations of DDR’s experienced playerbase at UCSD’s annual animefest event to emphasize data science in practice - potentially using our work to get more students at UCSD into rhythm games.

# %% [markdown]
# ## Authors
#
# TEAM LIST AND CREDITS
#
# Eljin Vedar
# Writing – original draft, Writing –  review & editing, conceptualization, project administration
#
# Isaac Chen
# Writing – original draft, Writing –  review & editing, analysis, visualization
#
# Jiafan Du
# Writing – original draft, Writing –  review & editing, data curation, analysis, software, visualization
#
# Robin Villareal
# Writing – original draft, Writing –  review & editing, experimental investigation
#
# Barry Tunstall
# Writing – original draft, Writing –  review & editing, data curation, analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# “How well does performance on a Dance Dance Revolution chart with difficulty X, defined by the game’s numeric rating, predict a player’s overall skill level across songs of varying difficulty?”
#
#
# For this idea, we aim to address the new player approach to finding a difficulty range. For our rhythm game of interest, we will choose Dance Dance Revolution (DDR), a classic rhythm game. Starting out, it may feel like the game is too easy or too hard. Given pre-existing game stats, we will analyze the data given by a player to make a prediction of their current skill range, or what difficulty X number a player can attempt on average. Furthermore, with this prediction, we can go further into recommending new songs for a player to try out relative to their corresponding difficulty X.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# As members of the Dance and Rhythm Game Club, we stand to address socioeconomic factors by making arcade rhythm games accessible. We understand the constraints of accessibility to an arcade, time, and disposable income play in being able to experience arcade rhythm games like Dance Dance Revolution (DDR) . It is one of our motivations to implore the general public to try DDR as we bring the arcade experience to campus. As we seek to expand our community, one of the problems we face when reaching out to new players is the willingness to try the game i.e not knowing where to begin. We run into phrases such as “I’m not good”, “I’ve never played before”, and even “I don’t even know where to start!” constantly. To that, we want to devise a method that involves a beginner friendly approach; easing players into DDR assuming they have no experience but an eagerness to learn. For the project, we used three sources based on their relevance to predictive analysis to form the foundation of our research.
#
#  The paper, “Dance Dance Convolution,” [3](#ref3) is a study that attempts to generate DDR step charts based on machine learning, with two inputs - an audio file, and a desired difficulty. The model would then generate a fully playable chart by decomposing the task into two sequential prediction problems: first determining when steps should occur, and then determining which arrows should be placed at each predicted timing. The results were analyzed based on how similar they were to the original chart - things like average hold note length, arrow selection, and beat placement. The important conclusions that come from the study was the capacity to assign chart difficulty ratings for procedurally generated charts based on note densities, although limited to a max bpm of 120; expanded on in a revisit in 2025 [1](#ref1) which includes a refined version exceeding the 120 bpm threshold. Another useful prediction scheme was being able to predict the chart difficulty [2](#ref2) based on attributes we have assigned as step data and technique data.
# The main takeaway from the results of the paper, for our uses, is the conclusion that DDR charting aligns closely with underlying musical structure, and that difficulty can be linearly correlated with step frequency, rhythmic density, and other computationally extractable metrics. This is useful for our predictive modeling because it suggests that the player performance data we gather, such as timing accuracy, hit‑window distribution, and error frequency can also be correlated with chart difficulty in a uniform way. Thus, the same mathematical relationships that allow systems like DDC to infer difficulty from audio and chart context can be inverted in our analysis - we can infer a player's effective skill level by measuring how their accuracy degrades or holds steady across segments of varying structural difficulty.
#
# The “Dance Dance ConvLSTM” [1](#ref1) paper is an extension of this paper, diving deeper into subsections of charting in order to further quantify patterns that arise in step charting - correlated to chart triggers such as music speedups, slowdowns, or certain step patterns, such as repeated notes on the same arrow - these are usually considered to be more difficult to execute than standard patterning. [2](#ref2) This provides a further foundation for our analysis: if machine‑learning models can reliably infer difficulty from musical and structural cues, then player‑performance data should likewise reflect predictable responses to those same cues, enabling skill prediction through our structural‑difficulty analysis.
#
# The third paper, “Predicting Chart Difficulty in Rhythm Games Through Classification Using Chart Pattern Derived Attributes,” also deals with the subject of correlating the in-game difficulty numbers with actual difficulty. Their analysis deals with difficulty and correlating it with chart structure - The main conclusions from the paper, useful for our purposes, is that objective structural difficulty can be quantified and measured, and that the charting in the game’s maps is correlated with this difficulty. [3](#ref3) This is useful for us because it means that we can apply a similar analysis to player skill, since performance data (such as timing accuracy, error rate, and stamina degradation, etc.) should correlate with these same difficulty signifiers in the charts. Essentially, If difficulty can be reliably inferred from chart patterns, then player capability can be inferred from how well a player handles those patterns.
#
# From the articles and our own playing experience, we found 3 distinct data categories relevant to our project:
# 1. Song Data (exact song) - data showing the title, artist, and folder the song is located in. This is important because there are versions of DDR that run on a different difficulty scale; making sure the songs user play are in the arcade version of the game.
#
# 2. Chart Data (Difficulty X) - The degree of gameplay a player can encounter during a song. Individual songs in DDR can be played on varying difficulty levels. Each difficulty iteration is commonly referred to as a chart. Charts are given numerical values assigned by DDR from 1-20 (we will assign this number to X). As the number increases, players can expect an increase of notes on the screen (note density) and rhythmic patterns. Charts of equal value have the tendency to feature similar complexity. For example, Song A with difficulty 5 will be as equal as Song B with difficulty 5 in terms of chart complexity.
#
# 3. Performance data (how a player does) - the overall score an individual obtains along with a timeline of where the player missed notes. This works in tandem with step data and technique data to evaluate what core fundamentals the person has/needs improvement on. In our project, we will use some of DDR's iconic scoring systems to assess new players (more info in HYPOTHESIS)
#
#
#
# Although these articles make great strides in the development of generated difficulty, we find the limitation of these contexts to engage with the new player community and the base game of DDR. Having the opportunity to expand on these works, we want to take chart predictions and the data acquired to contextualize them for the use of a new player; giving them a direction as they start their rhythm game journey.
#
# 1. <a name="ref1"> </a> O’Malley, Miguel. Dance Dance ConvLSTM. 2025, arXiv:2507.01644. https://arxiv.org/pdf/2507.01644
# 2. <a name="ref2"> </a>Caronongan, Arturo P., III, and Nelson A. Marcos. “Predicting Chart Difficulty in Rhythm Games Through Classification Using Chart Pattern Derived Attributes.” Computational Science and Technology, 2021, pp. 193–205. Springer Nature. https://link.springer.com/chapter/10.1007/978-981-33-4069-5_17
# 3. <a name="ref3"> </a>Donahue, Chris, Zachary C. Lipton, and Julian McAuley. “Dance Dance Convolution.” Proceedings of the 34th International Conference on Machine Learning, PMLR 70, 2017. https://proceedings.mlr.press/v70/donahue17a/donahue17a.pdf

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# As players take on higher difficulty X ratings, DDR charts demand greater stamina, precision, and pattern recognition due to chart complexity increasing (i.e total stepcount, rhythms implemented, how many notes appear at once). Therefore, players who achieve EX% around the community avg EX% reflect the capacity to comprehend and execute these factors. We come to this conclusion since chart complexity can be generalized across songs of equal difficulty X rating; reflecting their underlying skill.
#
#
# We predict a strong correlation between a player's EX% reflecting their overall skill level when compared to the avg EX%.
#
#
# To analyze the skill of a player, we have used/adjusted preexisting variables DDR currently implements to assess players:
# 1. Difficulty X - As stated previously, DDR difficulty has a rating numbered from easiest to hardest: 1-20. DDR includes 4 standard labels: BEGINNER 1-4 , BASIC 3-7, DIFFICULT 5-9, EXPERT 10-13+. One issue that has arisen was the overlapping ranges in the standard labels. As an example, one song can have a BASIC 7, while another song can have a DIFFICULT 7 even though there is no major difficulty spike between the two. For a new player, seeing DIFFICULT 7 instead of BASIC 7 may afflict a bias when choosing the difficulty. To avoid ambiguity, we want to simplify the system purely on the numeric RATING; assigning it to our variable, X (X can range from 1-20). When we refer to difficulty X now, it provides a clearer representation of difficulty while still utilizing the pre-existing DDR system. (a 7 is a 7!).
#
#
# 2. EX - EX is a scoring system originating from DDR EXTREME; independent from the in game combo and life bar players use. EX was designed to be a timing-based accuracy score, given by the summation of the 2 best timing judgements - Marvelous and Perfect. To calculate EX, the formula is given below:
#
#         EX = ∑ 2(Marvelous) + 1(Perfect)
#
#
#
# 3. EX% - EX% is EX normalized. Because charts have varying total notecounts EX alone is
# Not enough to determine overall skill level. By normalizing EX, we obtain a metric that allows us to compare charts of different total notecounts. To calculate EX% we use the formula:
#
#         EX% = EX/(3 x Total Notecount)
#
#
# 4. median EX% (med EX%)  - The median EX% on a given song that will give us the baseline for a player's performance in relation to players who also attempted  chart difficulty X. We understand that one of the constraints of community-driven data is the possibility of inflated averages due to the data coming from registered users. These registered users offer a higher level of time commitment and scoring data than our new player demographic. For our project Median EX% is used to operationalize target performance that a player must achieve to be considered for that difficulty X skill level.
#
#
# 5. Overall skill level - A player's overall skill level is operationalized as their individual EX% on a difficulty X chart in relation to the given difficulty X’s median EX%. This is best represented by the difficulty X they can reliably play.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: DDR BPI / Skill Attack data
#   - Link to the dataset ORIGINAL SOURCE: http://ddr.kitaru.online/
#
#     Dataset as Spreadsheet: https://docs.google.com/spreadsheets/d/1_vvxS71takEt3gIjkC2vcrI6sHNfTwWKtSoETwBmY5E/edit?gid=660287600#gid=660287600
#
#   - Number of observations: 5894
#
#   - Number of variables: 15
#
#   - Description of the variables most relevant to this project
#
#     1. DIFFICULTY X - Numeric difficulty of a song
#
#     2. Max EX - Maximum possible EX score on a given chart
#
#     3. PLAYERS - How many players attempted the given chart
#
#   - Descriptions of any shortcomings this dataset has with respect to the project
#
#     The dataset includes songs outside the arcade version of DDR. Although songs outside the arcade version may adopt a difficulty X, there IS a noticeable spike in difficulty compared to an arcade song counterpart, so we seek to remove them from our dataset. Including them may also have an affect on our median EX%.
#
# - Dataset #2
#   - Dataset Name: Single (Chart Analyzer)
#   - Link to the dataset ORIGINAL SOURCE: https://zenius-i-vanisher.com/v5.2/thread?threadid=11287
#
#   Dataset as Spreadsheet: https://docs.google.com/spreadsheets/d/10NT1VPYV8JHEpi68SBCTApOO5mWEjIAbJP3C5Csthyk/edit?gid=2049250718#gid=2049250718
#   - Number of observations: 12866
#
#   - Number of variables: 260
#   - Description of the variables most relevant to this project
#
#     1. AC - A song is featured in the arcade version of the game
#
#     2. INTL - the song is present in ALL regions an arcade version exists.
#
#
#   - Descriptions of any shortcomings this dataset has with respect to the project
#
#     Most of the relevant data overlaps with dataset 1 but is even more skewed because the averages are in tandem with all songs of a corresponding difficulty X, even if they are outside the arcade version of the game.
#
# - Dataset #3
#   - Dataset Name: Animefest Player Scores
#   - Link to the dataset: https://github.com/COGS108/Group051_WI26/blob/64df21f9fb6148e4e860e4b8c466c7080442b57d/data/00-raw/parsed.csv
#   - Number of observations: 198
#   - Number of variables: 49
#
#   - Description of the variables most relevant to this project
#     1. Title - What song they played
#     2. Difficulty - uses their beginner/basic/difficult/expert labels
#     3.  Score - EX scores are given as EX x 1,000,000
#
#   - Descriptions of any shortcomings this dataset has with repsect to the project
#
#     Because the dataset uses the beginner/basic/difficult/expert labels we will have to search through the other sets for their numeric ratings. Another concern is the EX score is scaled by 1,000,000 so all EX scores from this dataset must be divided by 1,000,000 before it can be comparable to the averages.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group051_WI26/64df21f9fb6148e4e860e4b8c466c7080442b57d/data/00-raw/DDR%20BPI%20_%20Skill%20Attack%20data%20-%20bpi.csv', 'filename':'DDR BPI _ Skill Attack data - bpi.csv'},
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group051_WI26/64df21f9fb6148e4e860e4b8c466c7080442b57d/data/00-raw/DanceDanceRevolution%20Chart%20Data%20Spreadsheet%20-%20Single%20(Chart%20Analyzer).csv', 'filename':'DanceDanceRevolution Chart Data Spreadsheet - Single (Chart Analyzer).csv'},
    { 'url': 'https://raw.githubusercontent.com/COGS108/Group051_WI26/refs/heads/master/data/00-raw/parsed.csv', 'filename':'parsed.csv' }
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:  33%|███▎      | 1/3 [00:00<00:00,  2.07it/s]
# Successfully downloaded: DDR BPI _ Skill Attack data - bpi.csv
# Overall Download Progress:  67%|██████▋   | 2/3 [00:04<00:02,  2.54s/it]
# Successfully downloaded: DanceDanceRevolution Chart Data Spreadsheet - Single (Chart Analyzer).csv
# Overall Download Progress: 100%|██████████| 3/3 [00:04<00:00,  1.63s/it]
# Successfully downloaded: parsed.csv

# %% [markdown]
# ### DDR BPI/Skill Attack Performance
# The DDR BPI/Skill Attack Performance Dataset is a community-driven dataset that catalogs performance based statistics given by registered users who uploaded their playing data. Each row corresponds to a specific song, difficulty level/rating, and provides important statistics such as the average EX score obtained along and how many players were involved to produce those averages. The relevant columns from the dataset are as follows:
#
# diff - Numeric difficulty of a song. Can take a value between 1-20
#
# Max EX - Maximum possible EX score on a given chart
#
# PLAYERS - How many players attempted the given chart
#
# A central metric in this dataset is the EX score, which is the accuracy‑based scoring system that is the foundation of our project (EX Formula). These EX’s are important to log when we start converting them into EX%’s.
#
# One major concern of the dataset is how it is community-driven by registered users. We are building our averages on self-selected players who are willing to upload their scoring data for review. This may lead to introducing our target audience of newer players to the standards of the competitive scene. Through statistical analysis, we will attempt to make newer players comparable with some of the expected high averages via computing median EX% instead.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
from scipy import stats
import math
Dataset1 = pd.read_csv('data/00-raw/DDR BPI _ Skill Attack data - bpi.csv') # Read the raw data into a dataframe
display(Dataset1)
# Out:
#                               title      id chart  90% EX bpi  avg EX  90% EX  \
# 0                          ENDYMION   756.0   CDP      105.76   525.0  2511.0
# 1               BREAKING THE FUTURE  1188.0   CDP      105.22   724.0  2443.0
# 2                        EGOISM 440   640.0   CDP      104.70   369.0  2157.0
# 3               BREAKING THE FUTURE  1188.0   CSP      104.22  1071.0  2605.0
# 4     Over The &ldquo;Period&rdquo;   648.0   CDP      103.90   546.0  2116.0
# ...                             ...     ...   ...         ...     ...     ...
# 9612                 MAKE IT BETTER     NaN   NaN         NaN     NaN     NaN
# 9613                 MAKE IT BETTER     NaN   NaN         NaN     NaN     NaN
# 9614                 MAKE IT BETTER     NaN   NaN         NaN     NaN     NaN
# 9615                 MAKE IT BETTER     NaN   NaN         NaN     NaN     NaN
# 9616                 MAKE IT BETTER     NaN   NaN         NaN     NaN     NaN
#
# ...

# %% [markdown]
# As seen above this data is already tidy and in a usable format. The dataset looks tidy on the surface because it has consistent column names, each row represents one chart, numeric columns are mostly numeric, there are no obvious formatting errors, and the structure is already tidy (one row per chart, one column per variable). The dataset has 9617 Entries and 15 columns of data. Next we'll clean the data and find where and how data is missing.

# %%
Dataset1[Dataset1.isnull().any(axis=1)] # Display rows with a null value
# Out:
#                title  id chart  90% EX bpi  avg EX  90% EX  wr EX  max EX  \
# 9116  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9117  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9118  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9119  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9120  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# ...              ...  ..   ...         ...     ...     ...    ...     ...
# 9612  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9613  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9614  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9615  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
# 9616  MAKE IT BETTER NaN   NaN         NaN     NaN     NaN    NaN     NaN
#
#       diff  avg money  wr money  players  mfcs  notecount  untimed
# ...

# %% [markdown]
# All missing data contained in this dataset is on rows 9116-9616 (501) and they all contain no variables thus they can be dropped for the purposes of this project.

# %%
Dataset1 = Dataset1.dropna()
Dataset1
# Out:
#                               title      id  chart  90% EX bpi       avg EX  \
# 0                          ENDYMION   756.0    CDP      105.76   525.000000
# 1               BREAKING THE FUTURE  1188.0    CDP      105.22   724.000000
# 2                        EGOISM 440   640.0    CDP      104.70   369.000000
# 3               BREAKING THE FUTURE  1188.0    CSP      104.22  1071.000000
# 4     Over The &ldquo;Period&rdquo;   648.0    CDP      103.90   546.000000
# ...                             ...     ...    ...         ...          ...
# 9111                   SAY A PRAYER  1191.0  begSP        -inf   129.281107
# 9112                Chromatic Burst  1199.0  begSP        -inf   125.816852
# 9113                      千客万来☆無問題！  1244.0  begSP        -inf   261.326531
# 9114                        走れメロンパン  1247.0  begSP        -inf   156.931818
# 9115                  melody H4CKER  1260.0  begSP        -inf   191.804002
#
# ...

# %% [markdown]
# After dropping missing rows we are left with 9116 Entries in this dataset. Next we'll search for outliers and suspicious entries

# %%
Dataset1.describe()
# Out:
#                 id   90% EX bpi       avg EX       90% EX        wr EX  \
# count  9116.000000  9116.000000  9116.000000  9116.000000  9116.000000
# mean    636.326349         -inf   753.763501   828.215774   918.483107
# std     359.100714          NaN   354.950138   442.108494   486.212369
# min       0.000000         -inf    63.747588    62.000000    69.000000
# 25%     339.750000     0.057804   479.157693   493.250000   548.250000
# 50%     632.500000     0.730000   709.630595   750.000000   834.000000
# 75%     944.000000     2.500000   983.000000  1074.000000  1191.000000
# max    1260.000000   105.760000  2118.326556  2867.000000  3016.000000
#
#             max EX         diff      avg money        wr money      players  \
# count  9116.000000  9116.000000    9116.000000     9116.000000  9116.000000
# mean    920.738372     9.092804  958811.723892   999874.542563   552.164765
# std     491.227426     4.171732   46409.852708     2679.951383   537.368528
# ...

# %% [markdown]
# Based on these results if we choose to work with '90% EX bpi' we'll need to be careful to work around the -inf values. Other than this no glaring outliers are instantly visible. We can then perform an IQR check.

# %%
df = Dataset1

# numeric-only for outlier detection
num = df.select_dtypes(include="number")
m = num.shape[1]
x=.05
# tail cutoffs
lo = num.quantile(0.01)
hi = num.quantile(0.99)

# True where a value is in the extreme tails of its column
outlier_mask = num.lt(lo) | num.gt(hi)

# require at least k columns in the row to be flagged
k = max(2, math.ceil(x * m)) 

row_outlier_counts = outlier_mask.sum(axis=1)
rows_flagged = row_outlier_counts >= k

print("Total rows:", len(df))
print(f"Rows flagged (>= {k} columns ({x*100}% of columns) extreme):", rows_flagged.sum())

# show the worst rows first (most flagged columns)
worst_idx = row_outlier_counts.sort_values(ascending=False).head(50).index

# full set of flagged rows (all columns)
df_flagged = df.loc[rows_flagged].copy()
df.loc[worst_idx].assign(outlier_flag_count=row_outlier_counts.loc[worst_idx]).head(rows_flagged.sum()).head(10)
# Out:
# Total rows: 9116
# Rows flagged (>= 2 columns (5.0% of columns) extreme): 325
#                               title      id  chart  90% EX bpi       avg EX  \
# 9                                 鳳  1234.0    CDP  101.770000   978.000000
# 7                                 鳳  1234.0    CSP  102.130000   941.000000
# 9047                     Hold Tight  1169.0  begSP -683.043458   125.681738
# 11                         VOLAQUAS  1150.0    CDP  100.410000  1063.000000
# 9084                      BAD GIRLS   473.0  begSP        -inf   136.616298
# 69    Over The &ldquo;Period&rdquo;   648.0    CSP   33.130000  1022.000000
# 29                         ENDYMION   756.0    CSP   48.110000   925.000000
# 9095                        Surface  1061.0  begSP        -inf   130.602529
# 9089                Choo Choo TRAIN   543.0  begSP        -inf   129.219749
# 6        Lachryma《Re:Queen&rsquo;M》   920.0    CDP  102.170000  1036.000000
#
# ...

# %% [markdown]
# Based on this tail-based check, 325 of 9,617 rows (~3.4%) were flagged as extreme in at least 2 numeric columns. This rate may be inflated by the presence of -inf values (notably in the 90% EX BPI column), which we will replace/handle before running EDA or making any decisions about true outliers. After addressing those invalid values, we can save the cleaned, tidy DataFrame to the interim data folder.

# %%
Dataset1.to_csv(r'data/01-interim/bpi_interim.csv', index=False)

# %% [markdown]
# ### Data Cleaning: DDR BPI/Skill Attack Performance
# For Dataset 1, the raw table was already tidy (one row per observation, one column per variable). The only cleaning needed was removing a small set of systematically incomplete rows with missing values.
#
# For dataset 1 all that is left for us is to eliminate columns and rows that are unnecessary for our project purpose such as the excess variables that we did not see as important or songs that are not part of the arcade version of DDR (which we will cross reference once we combine the data used from dataset 2).

# %% [markdown]
# ### Single (Chart Analyzer)
# Single (chart analyzer) provides a similar approach to DDR BPI/Skill Attack Performance but integrates performance data from DDR GRAND PRIX and online version of DDR that may include custom songs or modified difficulties. Because of this, we can not use the provided EX scores. The main reason we included this dataset was because Single (chart analyzer) has a more in-depth approach to song titles. Song titles in this dataset are labeled by their presence in the DDR scene - giving us an indicator if a song is available in an arcade version of DDR. The 2 main variables we must pay attention to are the following:
#
# AC - arcade cabinet
#
# INTL - international
#
# By finding songs with these labels, we can conclude if the song is 1. In the arcade version an 2. Accessible to anyone no matter the arcade. By crossreferencing this dataset with DDR BPI/Skill Attack Performance, we make our personal song encyclopedia even stronger. Limitations were already expressed through the statistics being invalid from this dataset. The important takeaway was song verification.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
Dataset2 = pd.read_csv('data/00-raw/DanceDanceRevolution Chart Data Spreadsheet - Single (Chart Analyzer).csv', low_memory=False) # Read raw data into DF solving for DtypeWarning
display(Dataset2)
#Dataset2.isna().sum().sum()
#Dataset2[Dataset2.isna().any(axis=1)]
# Out:
#                       Folder  \
# 0              DDR (AC) (JP)
# 1              DDR (AC) (JP)
# 2              DDR (AC) (JP)
# 3              DDR (AC) (JP)
# 4              DDR (AC) (JP)
# ...                      ...
# 12860  OHA-STA DDR (PS) (JP)
# 12861  OHA-STA DDR (PS) (JP)
# 12862  OHA-STA DDR (PS) (JP)
# 12863  OHA-STA DDR (PS) (JP)
# 12864  OHA-STA DDR (PS) (JP)
#
#                                                    Title Difficulty  Rating  \
# 0                                              Butterfly   Beginner       2
# 1                                              Butterfly      Basic       5
# 2                                              Butterfly  Difficult       6
# 3                                              Butterfly     Expert       8
# 4                                              Butterfly  Challenge      11
# ...                                                  ...        ...     ...
# ...

# %% [markdown]
# As seen above this data is already tidy and in a usable format. The dataset looks tidy on the surface because it has consistent column names, each row represents one Chart, numeric columns are mostly numeric, there are no obvious formatting errors, and the structure is already tidy (one row per chart, one column per variable). The dataset has 12865 Entries and 260 columns of data. Next we'll clean the data and find where and how data is missing.

# %%
print("Sum of NaN's " + str(Dataset2.isna().sum().sum())) # Print total number of NaN's in the dataset
null_locs = (Dataset2.isna().stack().loc[lambda s: s].reset_index().rename(columns={"level_0": "row", "level_1": "column", 0: "is_null"})) # Create filter which will show all NaN row and columns

null_locs[["row", "column"]].head(25) # Display results
# Out:
# Sum of NaN's 23
#      row                                         column
# 0   4434  Double-step (Avoid Twist While Facing S) (DS)
# 1   6209  Double-step (Avoid Twist While Facing S) (DS)
# 2   7423  Double-step (Avoid Twist While Facing S) (DS)
# 3   8311  Double-step (Avoid Twist While Facing S) (DS)
# 4   8331  Double-step (Avoid Twist While Facing S) (DS)
# 5   9526  Double-step (Avoid Twist While Facing S) (DS)
# 6   9643  Double-step (Avoid Twist While Facing S) (DS)
# 7   9920                    Double-steps Into Jacks (H)
# 8   9920                    Double-steps Into Jumps (H)
# 9   9920               Double-step (Avoid Facing S) (H)
# 10  9920                       Ended on Double-step (H)
# 11  9921                    Double-steps Into Jacks (H)
# 12  9921                    Double-steps Into Jumps (H)
# 13  9921               Double-step (Avoid Facing S) (H)
# 14  9921                       Ended on Double-step (H)
# ...

# %% [markdown]
# We can see there are a total of 11 rows which have null values, some have multiple Null values. None of these values are in columns of interest therefore we do not need to drop these rows for our future analysis. Next we'll look for outliers.

# %%
df = Dataset2

# numeric-only for outlier detection
num = df.select_dtypes(include="number")
m = num.shape[1]
x=.05
# tail cutoffs
lo = num.quantile(0.01)
hi = num.quantile(0.99)

# True where a value is in the extreme tails of its column
outlier_mask = num.lt(lo) | num.gt(hi)

# require at least k columns in the row to be flagged
k = max(2, math.ceil(x * m)) 

row_outlier_counts = outlier_mask.sum(axis=1)
rows_flagged = row_outlier_counts >= k

print("Total rows:", len(df))
print(f"Rows flagged (>= {k} columns ({x*100}% of columns) extreme):", rows_flagged.sum())

# show the worst rows first (most flagged columns)
worst_idx = row_outlier_counts.sort_values(ascending=False).head(50).index

# full set of flagged rows (all columns)
df_flagged = df.loc[rows_flagged].copy()
df.loc[worst_idx].assign(outlier_flag_count=row_outlier_counts.loc[worst_idx]).head(rows_flagged.sum()).head(10)
# Out:
# Total rows: 12865
# Rows flagged (>= 12 columns (5.0% of columns) extreme): 863
#                                  Folder  \
# 7459                  DDR II (Wii) (NA)
# 4057                  DDR A (AC) (INTL)
# 7458                  DDR II (Wii) (NA)
# 5362           DDR A20 PLUS (AC) (INTL)
# 6121                 DDR A3 (AC) (INTL)
# 2645          DDR ULTRAMIX4 (Xbox) (NA)
# 9140      DDR UNIVERSE2 (Xbox 360) (NA)
# 8345  DDR SuperNOVA Missions (PS2) (NA)
# 8344  DDR SuperNOVA Missions (PS2) (NA)
# 6271                 DDR A3 (AC) (INTL)
#
#                                                   Title     Difficulty  \
# 7459                               New Decade Full Song      Challenge
# 4057                                           ENDYMION      Challenge
# 7458                               New Decade Full Song         Expert
# 5362  灼熱 Pt.2 Long Train Running | Shakunetsu Pt.2 L...      Challenge
# 6121           量子の海のリントヴルム | Ryoushi no umi no Lindwurm      Challenge
# ...

# %% [markdown]
# Based on the 1st/99th-percentile tail check, 863 of 12,865 rows (~6.7%) were flagged as extreme in at least 12 numeric columns. This indicates a substantial number of observations with unusually high/low values across multiple measures, suggesting either genuine multi-metric extremes or distributions with heavy tails (i.e., not close to normal). After a quick review of these flagged rows to confirm they aren’t data errors, we can save the cleaned, tidy DataFrame to the interim folder.

# %%
Dataset2.to_csv(r'data/01-interim/Single_chart_analyzer.csv', index=False)

# %% [markdown]
# ### Data Cleaning: Single (Chart Analyzer)
# Dataset 2 follows the same structure as Dataset 1 and upholds the same properties:
#
# it has consistent column names
#
# each row represents one chart
#
# numeric columns are mostly numeric
#
# there are no obvious formatting errors
#
# the structure is already tidy
#
# In terms of our project Dataset 2 does have more unnecessary variables we will have to filter out since this dataset is used merely for cross referencing arcade song presence.

# %% [markdown]
# ### Animefest Player Scores (parsed.csv)
# Animefest Player Scores is our first attempt to apply our model to a sample of new players during UCSD Animefest 2026. Our start time was 12:00pm and ended around 7:30pm. To take the data we used an online program of DDR called “Simply Love (v.5.1)” to mimic the arcade experience. From this data, the most relevant variables are the following:
#
# Song_dir - What song they played
#
# difficulty - uses their beginner/basic/difficult/expert labels
#
# score - EX scores are given as EX x 1,000,000
#
# The big concern during animefest was that we anticipated most people would like to play “anime” songs. Anime songs are usually custom charted and do not reflect chart complexity for standard DDR charts. Because we prioritize the well-being of our community, we would not interfere with song selection, but came to terms with the amount of valid data provided being significantly less than reported.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
Dataset3 = pd.read_csv('data/00-raw/parsed.csv') # Read csv into dataframe
parts = Dataset3["song_dir"].str.strip("/").str.split("/") # Split song_dir into root, folder, and song name
Dataset3.insert(1,'Folder', parts.str[-2]) # Set folder column to be first and use folder values
Dataset3.insert(2,'Title', parts.str[-1]) # Set Title column to be second and use Title (song name) values
Dataset3 = Dataset3.drop(columns=["Unnamed: 0", "song_dir"], errors="ignore") # Drop old song_dir and previous index coolumn
display(Dataset3)
Dataset3.isna().sum() #find categories with null values
# Out:
#                    Folder                        Title difficulty  \
# 0            DDR A20 PLUS            Midnight Amaretto     Medium
# 1            DDR A20 PLUS            Midnight Amaretto     Medium
# 2    Jubo 2022 OtakuVibes  KICK BACK [Chainsaw Man OP]     Medium
# 3    Jubo 2022 OtakuVibes  KICK BACK [Chainsaw Man OP]     Medium
# 4                   DDR A                   Koishigure     Medium
# ..                    ...                          ...        ...
# 192             DDR WORLD            Funky Flux Fusion       Hard
# 193             DDR WORLD             Gravity Collapse       Easy
# 194             DDR WORLD             Gravity Collapse  Challenge
# 195             DDR WORLD           Time to HYPERDRIVE       Hard
# 196                DDR X2      roppongi EVOLVED ver. D       Hard
#
#        steps_type  name   grade     score  percentdp  surviveseconds  \
# 0    dance-single   NaN  Failed  30024405     0.2871       78.376266
# ...

# %% [markdown]
# As seen above this data is already tidy and in a usable format. The dataset looks tidy on the surface because it has consistent column names, each row represents one person, numeric columns are mostly numeric, there are no obvious formatting errors, and the structure is already tidy (one row per person, one column per variable). The dataset has 197 Entries and 49 columns of data. Of these 49 columns 3 have a majority NaN values "name", "stageaward", and "peakcomboaward". Because there isn't enough data for these rows to be useful they will be dropped.

# %%
Dataset3 = Dataset3.drop(columns=(["name", "stageaward", "peakcomboaward"]))
Dataset3.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# After cleaning there are 197 rows and 46 columns. We can now look for outliers.

# %%
df = Dataset3

# numeric-only for outlier detection
num = df.select_dtypes(include="number")
m = num.shape[1]
x=.05
# tail cutoffs
lo = num.quantile(0.01)
hi = num.quantile(0.99)

# True where a value is in the extreme tails of its column
outlier_mask = num.lt(lo) | num.gt(hi)

# require at least k columns in the row to be flagged
k = max(2, math.ceil(x * m)) 

row_outlier_counts = outlier_mask.sum(axis=1)
rows_flagged = row_outlier_counts >= k

print("Total rows:", len(df))
print(f"Rows flagged (>= {k} columns ({x*100}% of columns) extreme):", rows_flagged.sum())

# show the worst rows first (most flagged columns)
worst_idx = row_outlier_counts.sort_values(ascending=False).head(50).index

# full set of flagged rows (all columns)
df_flagged = df.loc[rows_flagged].copy()
df.loc[worst_idx].assign(outlier_flag_count=row_outlier_counts.loc[worst_idx]).head(rows_flagged.sum()).head(10)
# Out:
# Total rows: 197
# Rows flagged (>= 2 columns (5.0% of columns) extreme): 16
#                                              Folder  \
# 169                                          DDR X2
# 113                                       DDR WORLD
# 145                                    DDR A20 PLUS
# 123  Touhou Fujinya ~ Touhou Pad Pack Rebirth (ITG)
# 155                                     DDR 6th Mix
# 195                                       DDR WORLD
# 183                            Jubo 2021 OtakuVibes
# 171                           In The Groove 2 (ITG)
# 180                            Jubo 2021 OtakuVibes
# 179                         DDR A (more up to date)
#
#                                                  Title difficulty  \
# 169                            roppongi EVOLVED ver. D       Hard
# 113                                Ohisashi chuukagai!   Beginner
# 145                                        ANTI ANTHEM       Hard
# ...

# %% [markdown]
# Based on the 1st/99th-percentile check, 16 of 197 rows (~8.1%) were flagged as extreme in at least 2 numeric columns. That suggests the dataset contains a non-trivial set of potential outliers. With this knowledge we can then save the resulting cleaned dataset to the interim folder.

# %%
Dataset3.to_csv(r'data/01-interim/parsed-interim.csv', index=False)

# %% [markdown]
# ### Data Cleaning: Animefest Player Scores
# Current issues with the data (raw):
#
# The title includes additional variables such as song pack origin and adds clutter to the title.
#
# Numeric rating was missing.
#
# EX score is scaled by 1,000,000.

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# ### Distribution of Difficulty X + EX %
# These shows how many charts exist at each difficulty rating, as well as how the accuracy is spread across them. It helps confirm whether the dataset is balanced or skewed toward certain levels. Since predicting player skill depends on understanding how players perform across the full difficulty spectrum, knowing the distribution ensures that we can account for any biases that exist within our dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import r2_score

df = pd.read_csv("data/01-interim/bpi_interim.csv")

# Basic overview
print(df.info())
print(df.describe())

# Create EX% column
df["EX_percent"] = df["avg EX"] / (3 * df["notecount"])

# Distribution plots
plt.figure(figsize=(10,5))
sns.histplot(df["diff"], bins=20, kde=True)
plt.title("Distribution of Difficulty X")
plt.xlabel("Difficulty X")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10,5))
sns.histplot(df["EX_percent"], bins=30, kde=True)
plt.title("Distribution of EX%")
plt.xlabel("EX%")
plt.ylabel("Count")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9116 entries, 0 to 9115
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       9116 non-null   object
#  1   id          9116 non-null   float64
#  2   chart       9116 non-null   object
#  3   90% EX bpi  9116 non-null   float64
#  4   avg EX      9116 non-null   float64
#  5   90% EX      9116 non-null   float64
#  6   wr EX       9116 non-null   float64
#  7   max EX      9116 non-null   float64
#  8   diff        9116 non-null   float64
#  9   avg money   9116 non-null   float64
#  10  wr money    9116 non-null   float64
#  11  players     9116 non-null   float64
#  12  mfcs        9116 non-null   float64
#  13  notecount   9116 non-null   float64
#  14  untimed     9116 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.0+ MB
# None
#                 id   90% EX bpi       avg EX       90% EX        wr EX  \
# ...

# %% [markdown]
# #### EX%
#
# Correlation Heatmap
# The heatmap shows relationships between difficulty, EX scores, notecount, and player counts. Strong correlations help identify which variables meaningfully contribute to predicting EX% and, by extension, player skill. For example, if EX% strongly correlates with difficulty or notecount, those variables become key predictors in the skill model.
#
# Difficulty X vs EX%
# This plot shows how accuracy changes as difficulty increases. A downward trend indicates that higher difficulty charts reduce EX%, which supports the claim that EX% reflects a player’s ability to handle more complex patterns. This relationship is a very important facet to predicting a player’s skill level.
#
# Notecount vs EX%
# This examines whether charts with more steps (higher stamina/complexity) lead to lower EX%. If EX% decreases as notecount increases, it suggests that stamina and density are important components of skill, and should be included in the predictive model.
#
# EX% ~ Difficulty X
# This model quantifies how much EX% changes with each increase in difficulty. The coefficient shows the expected drop in EX% per difficulty level, and the R² value indicates how much of a player’s performance can be explained by difficulty alone.

# %%
# Correlation heatmap
numeric_cols = ["diff", "avg EX", "max EX", "players", "notecount", "EX_percent"]
plt.figure(figsize=(10,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Scatterplots
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="diff", y="EX_percent", alpha=0.4)
plt.title("Difficulty X vs EX%")
plt.xlabel("Difficulty X")
plt.ylabel("EX%")
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="notecount", y="EX_percent", alpha=0.4)
plt.title("Notecount vs EX%")
plt.xlabel("Notecount")
plt.ylabel("EX%")
plt.show()

# Simple regression model:
# Predict EX% from difficulty X
X = df[["diff"]]
y = df["EX_percent"]

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
r2 = r2_score(y, y_pred)

print("\n==============================")
print("OLS Regression: EX% ~ Difficulty X")
print("==============================")
print(f"Intercept: {model.intercept_}")
print(f"Coefficient (Difficulty X): {model.coef_[0]}")
print(f"R-squared: {r2}")

plt.figure(figsize=(8,6))
sns.regplot(x="diff", y="EX_percent", data=df, scatter_kws={"alpha":0.3})
plt.title("Regression: Difficulty X → EX%")
plt.xlabel("Difficulty X")
plt.ylabel("EX%")
plt.show()

cluster_features = df[["diff", "EX_percent", "notecount"]]

scaler = StandardScaler()
scaled = scaler.fit_transform(cluster_features)

kmeans = KMeans(n_clusters=3, random_state=42)
df["skill_cluster"] = kmeans.fit_predict(scaled)

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="diff", y="EX_percent", hue="skill_cluster", palette="deep", alpha=0.5)
plt.title("Player Skill Clusters")
plt.xlabel("Difficulty X")
plt.ylabel("EX%")
plt.show()

var_by_diff = df.groupby("diff")["EX_percent"].var()

plt.figure(figsize=(10,5))
sns.lineplot(x=var_by_diff.index, y=var_by_diff.values)
plt.title("Variance of EX% by Difficulty")
plt.xlabel("Difficulty X")
plt.ylabel("Variance of EX%")
plt.show()

df["diff_bucket"] = pd.cut(df["diff"], bins=[0,5,10,15,20], labels=["1-5","6-10","11-15","16-20"])

bucket_stats = df.groupby("diff_bucket")["EX_percent"].median()
print(bucket_stats)

plt.figure(figsize=(8,5))
sns.barplot(x=bucket_stats.index, y=bucket_stats.values, palette="viridis")
plt.title("Median EX% by Difficulty Bucket")
plt.xlabel("Difficulty Range")
plt.ylabel("Median EX%")
plt.show()
# Out:
# ...
# OLS Regression: EX% ~ Difficulty X
# ...
# Intercept: 0.9515650024769777
# Coefficient (Difficulty X): -0.011714858393612712
# R-squared: 0.4508840262865258
# diff_bucket
# 1-5      0.898312
# 6-10     0.864583
# 11-15    0.833018
# 16-20    0.705270
# Name: EX_percent, dtype: float64
# C:\Users\eljin\AppData\Local\Temp\ipykernel_74400\3993582525.py:74: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bucket_stats = df.groupby("diff_bucket")["EX_percent"].median()
# C:\Users\eljin\AppData\Local\Temp\ipykernel_74400\3993582525.py:78: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bucket_stats.index, y=bucket_stats.values, palette="viridis")

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
#     We will be collecting data from AnimeFest, on February 14th using a DDR pad provided by the DRGC club on campus. We will brief attendees of our project, how their data is used, and that it is completely optional. We won’t be collecting signatures as it is already made anonymous by the software.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#     One form of collection bias we will encounter is the population we are sampling at AnimeFest. The majority of participants will most likely be UCSD students. Furthermore, we will be sampling from a small subset of UCSD students, those who are attending AnimeFest. However, we believe this bias will be negligible due to our other datasets being of varying age groups. Also, our goal is to collect a sample size of fifty to normalize the distribution.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#      PII will be minimized at AnimeFest since the software ensures anonymity.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
#    Addressed downstream bias in constraint and limitations of community-driven averages (how we got avg EX%) and how this may be an unfair comparison.  At animefest, we tried to keep players on the same settings so we can evaluate them equally, but this also opens the constraint of players having different preferences when playing rhythm games. When evaluating player performance, we must reason with if their score is in the scope of the avg EX%. One way we devised was calculating the IQR across difficulty X’s.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#     No, one of our references is a “living” document of all player data and serves as a valuable resource to the rhythm game community.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#     Relevant stakeholders include the high level/ optimization level players that are also accounted for in our dataset. This is something to be conscious about when looking at the scores relative to a predicted score of a new player. We have established a target demographic as the subject of interest in our rhythm game community. One other lingering concern would be DDR quality across all players. Some places do not take good care of their DDR machines and this leads to game impact (low sensitivity = losing score) and we acknowledge how this may affect averages.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#     One possible bias that we encounter will be in our dataset that takes in registered users. A possibility is that with a highly-motivated player base like DDR, there will be players who work on optimization of their scores and might play lower level difficulties for accuracy; these players will bring the average score up. This bias is mitigated by the large sample size.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#     Yes. All player data involved in calculations are stripped independently from the individual who produced them and the players remain anonymous. At most, there is a tie to their in-game username, but that can be excluded as well.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#      One of our resources is part of a living document that dates back almost 3 years ago.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#    Our dataset does not include protected attributes such as race, gender, or age, so inherently our analysis cannot discriminate upon these characteristics. To avoid proxy discrimination we use DDR’s performance-based metrics that treats an individual as equal among other players such as difficulty X, EX, EX% and avg EX%.
#
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
#     For metrics we have developed 4 categories of data collection that all work in tandem with each other.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#      We have communicated that our purpose is to appeal to the beginner/casual approach to starting rhythm games and the model will serve as a way to accommodate these members of our rhythm game community. Knowledge acquired through this data science may not serve a higher skill level, rather help reach out to those trying to get there.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#    Our model is designed to help new DDR players understand difficulty ranges through the numeric rating, but we understand using data geared toward the DDR community can result in skewed data that represents the competitive DDR scene via registered users. However, as a community that strives for improvement, these players unintentionally set a bar for players coming in; a bar that appears daunting at first. We will try our best to still represent our target demographic of new players while acknowledging long-time players.

# %% [markdown]
# ## Discussion and Conclusion
#
# We analyzed 9,116 DDR charts, and used EX% to compare performance across songs with different notecounts. Our visualizations revealed that as chart difficulty increased, player performance (EX%) decreased. The regression shows a 1% drop in EX% for each increase in difficulty level. Furthermore, with R^2 = 0.45, difficulty alone explains the variation in scores. Furthermore, the median EX% drops in our grouping with diff(1-5) = 0.90 the easiest charts, and diff(16-20) = 0.70 the hardest charts. Overall, our data suggests that difficulty is a solid indicator of a player’s performance.
#
#
# Through our work, we have developed research addressing our players in mind as opposed to research aimed at step chart developers.
#
# We hope to inform our new players of the importance of EX% as we learned it is a fundamental component to overall skill. EX% has shown to encompass the core of DDR, emphasized by its correlation to stamina, accuracy and difficulty X's. In an attempt to reach our active player-base, we find  our purpose in exploring these foundations to provide structure for new players to follow. they may find clearer goals to develop when attempting higher difficulty X's. With the publishing of community based research, we see a way to provide upcoming members with easily accessible learning tools/resources; fast-tracking them to strive in their DDR career.
#
# As a part of pursuing our research question. We did not find any contradictory results to our hypothesis - in fact, our results were in favor and support our outlook on rhythm games through the lens of DDR.
#
#
# The limitations of our work do come down to a biased sample in which we developed the foundations of our research. As our main dataset is community driven, we essentially asked the high achievers in our community to represent what should be considered as the average scores. We had attempted to address these concerns by using methods such as looking at medians and outliers, but we acknowledge how this may affect what new players will perceive as "average" in our community.
#
#
# Moving forward, we feel that the ideal data set would be derived from all arcade versions of DDR which encompass active players along with any form of "new" player to alleviate some of the biases in sample taking. Another step we considered was being able to convert community built charts into their respective difficulty range in terms of DDR's difficulty  X. Overall, the groundwork of more accessible tools/resources for evaluating skill sets up further studies on how we can decrease the learning curve of rhythm games to help players reach higher levels faster.
